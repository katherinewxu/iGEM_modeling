# %%
import pandas as pd
import requests
import gzip
import io

# %%
# URL of the gzipped CSV file
url = 'https://ftp.ncbi.nlm.nih.gov/geo/series/GSE174nnn/GSE174369/suppl/GSE174369_PerMeth.AllRegions.csv.gz'

# %%
# Fetch the gzipped file from the URL
response = requests.get(url)

# %%
# Ensure the request was successful
if response.status_code == 200:
    # Decompress the gzipped file
    with gzip.GzipFile(fileobj=io.BytesIO(response.content)) as f:
        # Load the CSV file into a pandas DataFrame
        df = pd.read_csv(f)
        # Display the first few rows of the DataFrame
    print(df.head())
    # Print the column names
    print("Column names:", df.columns.tolist())
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
#            Unnamed: 0  Day_0_Control_3_R1  Day_0_Control_3_R2  \
# 0    chr1.15750.16253           90.340909           79.000000
# 1    chr1.17349.17853           92.834891           79.646018
# 2    chr1.19016.20044           79.591837           85.106383
# 3    chr1.29253.29642            0.211864            0.000000
# 4  chr1.128751.129717           35.526316           27.027027
#
#    Day_0_Control_4_R1  Day_0_Control_4_R2  Day_0_Control_1_R1  \
# 0           90.000000           89.204545           82.304527
# 1           78.761062           93.536122           89.577465
# 2           60.869565           89.147287           82.978723
# 3            0.000000            0.543478            0.526316
# 4           39.226519           31.543624           31.496063
#
#    Day_0_Control_1_R2  Day_0_Control_2_R1  Day_0_Control_2_R2  \
# 0           80.295567           78.571429           50.000000
# 1           91.586538           85.795455           90.000000
# 2           88.095238           86.153846           86.428571
# 3            0.000000            1.204819            0.000000
# 4           34.586466           24.418605           23.255814
#
#    Day_0_FSHD2_3_R1  ...  Day_3_Control_2_R1  Day_3_Control_2_R2  \
# 0         84.117647  ...           80.769231           80.952381
# 1         86.033520  ...           91.798942           88.498403
# 2         87.254902  ...           78.431373           80.000000
# 3          0.000000  ...            0.301205            0.000000
# 4         38.709677  ...           34.693878           27.450980
#
#    Day_3_FSHD2_3_R1  Day_3_FSHD2_3_R2  Day_3_FSHD2_2_R1  Day_3_FSHD2_2_R2  \
# 0         74.193548         87.591241         88.339223         78.095238
# 1         85.915493         84.393064         88.830716         87.562189
# 2         88.356164         88.333333         95.564516        100.000000
# 3          0.000000          0.000000          0.619835          0.574713
# 4         59.259259         36.585366         27.272727         53.703704
#
#    Day_3_FSHD2_4_R1  Day_3_FSHD2_4_R2  Day_3_FSHD2_1_R1  Day_3_FSHD2_1_R2
# 0         90.117647         88.082902         85.620915         90.277778
# 1         84.180791         90.783410         91.866029         86.666667
# 2         86.548223         82.710280         80.147059         72.916667
# 3          0.000000          0.000000          0.823045          0.000000
# 4         31.736527         40.243902         42.105263         50.000000
#
# [5 rows x 49 columns]
# Column names: ['Unnamed: 0', 'Day_0_Control_3_R1', 'Day_0_Control_3_R2', 'Day_0_Control_4_R1', 'Day_0_Control_4_R2', 'Day_0_Control_1_R1', 'Day_0_Control_1_R2', 'Day_0_Control_2_R1', 'Day_0_Control_2_R2', 'Day_0_FSHD2_3_R1', 'Day_0_FSHD2_3_R2', 'Day_0_FSHD2_2_R1', 'Day_0_FSHD2_2_R2', 'Day_0_FSHD2_4_R1', 'Day_0_FSHD2_4_R2', 'Day_0_FSHD2_1_R1', 'Day_0_FSHD2_1_R2', 'Day_12_Control_3_R1', 'Day_12_Control_3_R2', 'Day_12_Control_4_R1', 'Day_12_Control_4_R2', 'Day_12_Control_1_R1', 'Day_12_Control_1_R2', 'Day_12_Control_2_R1', 'Day_12_Control_2_R2', 'Day_12_FSHD2_3_R1', 'Day_12_FSHD2_3_R2', 'Day_12_FSHD2_2_R1', 'Day_12_FSHD2_2_R2', 'Day_12_FSHD2_4_R1', 'Day_12_FSHD2_4_R2', 'Day_12_FSHD2_1_R1', 'Day_12_FSHD2_1_R2', 'Day_3_Control_3_R1', 'Day_3_Control_3_R2', 'Day_3_Control_4_R1', 'Day_3_Control_4_R2', 'Day_3_Control_1_R1', 'Day_3_Control_1_R2', 'Day_3_Control_2_R1', 'Day_3_Control_2_R2', 'Day_3_FSHD2_3_R1', 'Day_3_FSHD2_3_R2', 'Day_3_FSHD2_2_R1', 'Day_3_FSHD2_2_R2', 'Day_3_FSHD2_4_R1', 'Day_3_FSHD2_4_R2', 'Day_3_FSHD2_1_R1', 'Day_3_FSHD2_1_R2']

# %%
# Display basic information about the dataset
print(df.info())

# Display summary statistics
print(df.describe())

# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267882 entries, 0 to 267881
# Data columns (total 49 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           267882 non-null  object
#  1   Day_0_Control_3_R1   267882 non-null  float64
#  2   Day_0_Control_3_R2   267882 non-null  float64
#  3   Day_0_Control_4_R1   267882 non-null  float64
#  4   Day_0_Control_4_R2   267882 non-null  float64
#  5   Day_0_Control_1_R1   267882 non-null  float64
#  6   Day_0_Control_1_R2   267882 non-null  float64
#  7   Day_0_Control_2_R1   267882 non-null  float64
#  8   Day_0_Control_2_R2   267882 non-null  float64
#  9   Day_0_FSHD2_3_R1     267882 non-null  float64
#  10  Day_0_FSHD2_3_R2     267882 non-null  float64
#  11  Day_0_FSHD2_2_R1     267882 non-null  float64
#  12  Day_0_FSHD2_2_R2     267882 non-null  float64
#  13  Day_0_FSHD2_4_R1     267882 non-null  float64
#  14  Day_0_FSHD2_4_R2     267882 non-null  float64
#  15  Day_0_FSHD2_1_R1     267882 non-null  float64
#  16  Day_0_FSHD2_1_R2     267882 non-null  float64
#  17  Day_12_Control_3_R1  267882 non-null  float64
#  18  Day_12_Control_3_R2  267882 non-null  float64
#  19  Day_12_Control_4_R1  267882 non-null  float64
#  20  Day_12_Control_4_R2  267882 non-null  float64
#  21  Day_12_Control_1_R1  267882 non-null  float64
#  22  Day_12_Control_1_R2  267882 non-null  float64
#  23  Day_12_Control_2_R1  267882 non-null  float64
#  24  Day_12_Control_2_R2  267882 non-null  float64
#  25  Day_12_FSHD2_3_R1    267882 non-null  float64
#  26  Day_12_FSHD2_3_R2    267882 non-null  float64
#  27  Day_12_FSHD2_2_R1    267882 non-null  float64
#  28  Day_12_FSHD2_2_R2    267882 non-null  float64
#  29  Day_12_FSHD2_4_R1    267882 non-null  float64
#  30  Day_12_FSHD2_4_R2    267882 non-null  float64
#  31  Day_12_FSHD2_1_R1    267882 non-null  float64
#  32  Day_12_FSHD2_1_R2    267882 non-null  float64
#  33  Day_3_Control_3_R1   267882 non-null  float64
#  34  Day_3_Control_3_R2   267882 non-null  float64
#  35  Day_3_Control_4_R1   267882 non-null  float64
#  36  Day_3_Control_4_R2   267882 non-null  float64
#  37  Day_3_Control_1_R1   267882 non-null  float64
#  38  Day_3_Control_1_R2   267882 non-null  float64
#  39  Day_3_Control_2_R1   267882 non-null  float64
#  40  Day_3_Control_2_R2   267882 non-null  float64
#  41  Day_3_FSHD2_3_R1     267882 non-null  float64
#  42  Day_3_FSHD2_3_R2     267882 non-null  float64
#  43  Day_3_FSHD2_2_R1     267882 non-null  float64
#  44  Day_3_FSHD2_2_R2     267882 non-null  float64
#  45  Day_3_FSHD2_4_R1     267882 non-null  float64
#  46  Day_3_FSHD2_4_R2     267882 non-null  float64
#  47  Day_3_FSHD2_1_R1     267882 non-null  float64
#  48  Day_3_FSHD2_1_R2     267882 non-null  float64
# dtypes: float64(48), object(1)
# memory usage: 100.1+ MB
# None
#        Day_0_Control_3_R1  Day_0_Control_3_R2  Day_0_Control_4_R1  \
# count       267882.000000       267882.000000       267882.000000
# mean            60.426557           60.353791           61.585495
# std             29.897198           29.868653           30.417992
# min              0.000000            0.000000            0.000000
# 25%             38.721805           38.655462           39.370491
# 50%             69.565217           69.356606           71.084337
# 75%             85.365854           85.263158           87.155963
# max            100.000000          100.000000          100.000000
#
#        Day_0_Control_4_R2  Day_0_Control_1_R1  Day_0_Control_1_R2  \
# count       267882.000000       267882.000000       267882.000000
# mean            60.616228           60.668117           60.652131
# std             30.906883           30.777109           30.709218
# min              0.000000            0.000000            0.000000
# 25%             37.055838           37.634409           37.790698
# 50%             69.819820           70.000000           70.093458
# 75%             86.956522           86.643836           86.585366
# max            100.000000          100.000000          100.000000
#
#        Day_0_Control_2_R1  Day_0_Control_2_R2  Day_0_FSHD2_3_R1  \
# count       267882.000000       267882.000000     267882.000000
# mean            59.876558           59.830262         60.501081
# std             31.076009           31.019127         30.438332
# min              0.000000            0.000000          0.000000
# 25%             35.789474           35.777126         38.118812
# 50%             69.014085           68.932039         70.093458
# 75%             86.348123           86.206897         85.922330
# max            100.000000          100.000000        100.000000
#
#        Day_0_FSHD2_3_R2  ...  Day_3_Control_2_R1  Day_3_Control_2_R2  \
# count     267882.000000  ...       267882.000000       267882.000000
# mean          60.398312  ...           61.153924           60.516282
# std           30.343914  ...           31.088471           31.132823
# min            0.000000  ...            0.000000            0.000000
# 25%           37.894737  ...           37.383394           36.521739
# 50%           69.921097  ...           70.833333           70.000000
# 75%           85.779817  ...           87.550201           87.005650
# max          100.000000  ...          100.000000          100.000000
#
#        Day_3_FSHD2_3_R1  Day_3_FSHD2_3_R2  Day_3_FSHD2_2_R1  Day_3_FSHD2_2_R2  \
# count     267882.000000     267882.000000     267882.000000     267882.000000
# mean          60.927460         60.933036         59.615533         59.601739
# std           30.890031         30.206734         30.342007         30.280101
# min            0.000000          0.000000          0.000000          0.000000
# 25%           37.951807         38.888889         36.566570         36.633663
# 50%           70.358212         70.479156         68.463612         68.269231
# 75%           86.842105         86.127168         85.394767         85.294118
# max          100.000000        100.000000        100.000000        100.000000
#
#        Day_3_FSHD2_4_R1  Day_3_FSHD2_4_R2  Day_3_FSHD2_1_R1  Day_3_FSHD2_1_R2
# count     267882.000000     267882.000000     267882.000000     267882.000000
# mean          61.586574         61.542283         61.397802         61.434788
# std           29.856881         29.834949         30.833642         30.686355
# min            0.000000          0.000000          0.000000          0.000000
# 25%           40.604532         40.441176         38.400000         38.734531
# 50%           71.091445         70.903482         71.604938         71.583234
# 75%           86.370974         86.308671         87.200378         87.095122
# max          100.000000        100.000000        100.000000        100.000000
#
# [8 rows x 48 columns]
# Missing values per column:
#  Unnamed: 0             0
# Day_0_Control_3_R1     0
# Day_0_Control_3_R2     0
# Day_0_Control_4_R1     0
# Day_0_Control_4_R2     0
# Day_0_Control_1_R1     0
# Day_0_Control_1_R2     0
# Day_0_Control_2_R1     0
# Day_0_Control_2_R2     0
# Day_0_FSHD2_3_R1       0
# Day_0_FSHD2_3_R2       0
# Day_0_FSHD2_2_R1       0
# Day_0_FSHD2_2_R2       0
# Day_0_FSHD2_4_R1       0
# Day_0_FSHD2_4_R2       0
# Day_0_FSHD2_1_R1       0
# Day_0_FSHD2_1_R2       0
# Day_12_Control_3_R1    0
# Day_12_Control_3_R2    0
# Day_12_Control_4_R1    0
# Day_12_Control_4_R2    0
# Day_12_Control_1_R1    0
# Day_12_Control_1_R2    0
# Day_12_Control_2_R1    0
# Day_12_Control_2_R2    0
# Day_12_FSHD2_3_R1      0
# Day_12_FSHD2_3_R2      0
# Day_12_FSHD2_2_R1      0
# Day_12_FSHD2_2_R2      0
# Day_12_FSHD2_4_R1      0
# Day_12_FSHD2_4_R2      0
# Day_12_FSHD2_1_R1      0
# Day_12_FSHD2_1_R2      0
# Day_3_Control_3_R1     0
# Day_3_Control_3_R2     0
# Day_3_Control_4_R1     0
# Day_3_Control_4_R2     0
# Day_3_Control_1_R1     0
# Day_3_Control_1_R2     0
# Day_3_Control_2_R1     0
# Day_3_Control_2_R2     0
# Day_3_FSHD2_3_R1       0
# Day_3_FSHD2_3_R2       0
# Day_3_FSHD2_2_R1       0
# Day_3_FSHD2_2_R2       0
# Day_3_FSHD2_4_R1       0
# Day_3_FSHD2_4_R2       0
# Day_3_FSHD2_1_R1       0
# Day_3_FSHD2_1_R2       0
# dtype: int64

# %%
# Rename the first column to 'region'
df.rename(columns={'Unnamed: 0': 'region'}, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Fill missing values using vectorized operations
df_melted.fillna(df_melted.mean(), inplace=True)

# Normalize methylation levels using vectorized operations
df_melted['normalized_methylation'] = (df_melted['methylation_level'] - df_melted['methylation_level'].mean()) / df_melted['methylation_level'].std()

# Display the first few rows of the preprocessed DataFrame
print(df_melted.head())
# Out:
#                region              sample  methylation_level
# 0    chr1.15750.16253  Day_0_Control_3_R1          90.340909
# 1    chr1.17349.17853  Day_0_Control_3_R1          92.834891
# 2    chr1.19016.20044  Day_0_Control_3_R1          79.591837
# 3    chr1.29253.29642  Day_0_Control_3_R1           0.211864
# 4  chr1.128751.129717  Day_0_Control_3_R1          35.526316

# %%
# Extract condition and time point from the 'sample' column
df_melted['condition'] = df_melted['sample'].apply(lambda x: 'Control' if 'Control' in x else 'FSHD2')
df_melted['time_point'] = df_melted['sample'].apply(lambda x: x.split('_')[1])

# Display the first few rows to verify
print(df_melted.head())
# Out:
#                region              sample  methylation_level condition  \
# 0    chr1.15750.16253  Day_0_Control_3_R1          90.340909   Control
# 1    chr1.17349.17853  Day_0_Control_3_R1          92.834891   Control
# 2    chr1.19016.20044  Day_0_Control_3_R1          79.591837   Control
# 3    chr1.29253.29642  Day_0_Control_3_R1           0.211864   Control
# 4  chr1.128751.129717  Day_0_Control_3_R1          35.526316   Control
#
#   time_point
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Sample a subset of the data for initial plots to speed up rendering
df_sample = df_melted.sample(frac=0.1, random_state=42)  # Sample 10% of the data

# Plot distribution of methylation levels
plt.figure(figsize=(10, 6))
sns.histplot(df_sample['methylation_level'], bins=50, kde=True)
plt.title('Distribution of Methylation Levels')
plt.xlabel('Methylation Level')
plt.ylabel('Frequency')
plt.show()

# Plot distribution by sample condition
plt.figure(figsize=(10, 6))
sns.boxplot(x='condition', y='methylation_level', data=df_sample)
plt.title('Methylation Levels by Condition')
plt.xlabel('Condition')
plt.ylabel('Methylation Level')
plt.show()

# %%
# Convert condition to category if not already
df_melted['condition'] = df_melted['condition'].astype('category')

# Quick summary using describe
print(df_melted.describe())
